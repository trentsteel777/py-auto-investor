# %%
import os
import pandas as pd

# %%
from load_data import share_prices_with_hv

# %%
DATA_DIR='data'

# %%
files = os.listdir(DATA_DIR)

# %%
files
# Out:
# ['AMZN.csv',
#  'BABA.csv',
#  'BKNG.csv',
#  'BRKR.csv',
#  'C.csv',
#  'CVS.csv',
#  'GOOG.csv',
#  'HCA.csv',
#  'JD.csv',
#  'MGM.csv',
#  'MTD.csv',
#  'NXST.csv',
#  'ORCL.csv',
#  'QRTEA.csv',
#  'SB.csv',
#  'SBLK.csv',
#  'SPY.csv',
#  'VTLE.csv',
#  'WBD.csv']

# %%
df_spy = share_prices_with_hv("SPY")

# %%
df_spy = df_spy.set_index(['Date'])

# %%
nc = dict(zip(df_spy.columns, [ "SPY_" + c for c in df_spy.columns]))

# %%
df_spy.rename(columns = nc, inplace = True)

# %%
df_spy
# Out:
#               SPY_Open    SPY_High     SPY_Low   SPY_Close  SPY_Adj Close  \
# Date
# 1993-02-01   43.968750   44.250000   43.968750   44.250000      25.017363
# 1993-02-02   44.218750   44.375000   44.125000   44.343750      25.070370
# 1993-02-03   44.406250   44.843750   44.375000   44.812500      25.335373
# 1993-02-04   44.968750   45.093750   44.468750   45.000000      25.441376
# 1993-02-05   44.968750   45.062500   44.718750   44.968750      25.423716
# ...                ...         ...         ...         ...            ...
# 2024-02-05  493.700012  494.380005  490.230011  492.549988     492.549988
# 2024-02-06  493.519989  494.320007  492.049988  493.980011     493.980011
# 2024-02-07  496.290009  498.529999  495.359985  498.100006     498.100006
# 2024-02-08  498.100006  498.709991  497.260010  498.320007     498.320007
# 2024-02-09  498.839996  501.649994  498.489990  501.200012     501.200012
#
#             SPY_Volume  SPY_Daily Return  SPY_Historical Volatility  \
# ...

# %%
df_amzn = share_prices_with_hv("AMZN")

# %%
df_amzn
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    1997-05-16    0.098438    0.098958    0.085417    0.086458    0.086458
# 1    1997-05-19    0.088021    0.088542    0.081250    0.085417    0.085417
# 2    1997-05-20    0.086458    0.087500    0.081771    0.081771    0.081771
# 3    1997-05-21    0.081771    0.082292    0.068750    0.071354    0.071354
# 4    1997-05-22    0.071875    0.072396    0.065625    0.069792    0.069792
# ...         ...         ...         ...         ...         ...         ...
# 6725 2024-02-07  169.479996  170.880005  168.940002  170.529999  170.529999
# 6726 2024-02-08  169.649994  171.429993  168.880005  169.839996  169.839996
# 6727 2024-02-09  170.899994  175.000000  170.580002  174.449997  174.449997
# 6728 2024-02-12  174.800003  175.389999  171.539993  172.339996  172.339996
# 6729 2024-02-13  167.729996  170.949997  165.750000  168.639999  168.639999
#
# ...

# %%
df_s = share_prices_with_hv("SPY")
df_a = share_prices_with_hv("AMZN")

# %%
df_s.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Daily Return', 'Historical Volatility', 'Annualized Volatility',
#        'macdfast', 'macdslow', 'macdsignal', 'stochslowk', 'stochslowd',
#        'sma_10'],
#       dtype='object')

# %%
df_a.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Daily Return', 'Historical Volatility', 'Annualized Volatility',
#        'macdfast', 'macdslow', 'macdsignal', 'stochslowk', 'stochslowd',
#        'sma_10', 'SYMBOL'],
#       dtype='object')

# %%
df_s["SYMBOL"] = "SPY"

# %%
df_a["SYMBOL"] = "AMZN"

# %%
df_m = pd.concat([df_s, df_a], ignore_index=True)

# %%
df_m.set_index(['Date', 'SYMBOL'], inplace=True)

# %%
df_m
# Out:
#                          Open        High         Low       Close   Adj Close  \
# Date       SYMBOL
# 1993-02-01 SPY      43.968750   44.250000   43.968750   44.250000   25.017363
# 1993-02-02 SPY      44.218750   44.375000   44.125000   44.343750   25.070370
# 1993-02-03 SPY      44.406250   44.843750   44.375000   44.812500   25.335373
# 1993-02-04 SPY      44.968750   45.093750   44.468750   45.000000   25.441376
# 1993-02-05 SPY      44.968750   45.062500   44.718750   44.968750   25.423716
# ...                       ...         ...         ...         ...         ...
# 2024-02-07 AMZN    169.479996  170.880005  168.940002  170.529999  170.529999
# 2024-02-08 AMZN    169.649994  171.429993  168.880005  169.839996  169.839996
# 2024-02-09 AMZN    170.899994  175.000000  170.580002  174.449997  174.449997
# 2024-02-12 AMZN    174.800003  175.389999  171.539993  172.339996  172.339996
# 2024-02-13 AMZN    167.729996  170.949997  165.750000  168.639999  168.639999
#
# ...

# %%
rows = df_m.loc["2024-02-08"]

# %%
for index, row in rows.iterrows():
    print(index)
# Out:
# SPY
# AMZN

# %%
df_m.loc["2024-02-08"]
# Out:
#               Open        High         Low       Close   Adj Close    Volume  \
# SYMBOL
# SPY     498.100006  498.709991  497.260010  498.320007  498.320007  52343600
# AMZN    169.649994  171.429993  168.880005  169.839996  169.839996  42316500
#
#         Daily Return  Historical Volatility  Annualized Volatility  macdfast  \
# SYMBOL
# SPY         0.000442               0.006981               0.110827  4.880314
# AMZN       -0.004046               0.020864               0.331211  4.321338
#
#         macdslow  macdsignal  stochslowk  stochslowd      sma_10
# SYMBOL
# SPY     4.312827    0.567487   93.394819   88.358096  491.895004
# AMZN    3.286850    1.034488   89.356196   82.721707  164.549997

# %%
for index, row in df_m.xs("SPY", level=1).iterrows():
    print(index)
# Out:
# 1993-02-01 00:00:00
# 1993-02-02 00:00:00
# 1993-02-03 00:00:00
# 1993-02-04 00:00:00
# 1993-02-05 00:00:00
# 1993-02-08 00:00:00
# 1993-02-09 00:00:00
# 1993-02-10 00:00:00
# 1993-02-11 00:00:00
# 1993-02-12 00:00:00
# 1993-02-16 00:00:00
# 1993-02-17 00:00:00
# 1993-02-18 00:00:00
# 1993-02-19 00:00:00
# 1993-02-22 00:00:00
# 1993-02-23 00:00:00
# 1993-02-24 00:00:00
# 1993-02-25 00:00:00
# 1993-02-26 00:00:00
# 1993-03-01 00:00:00
# 1993-03-02 00:00:00
# 1993-03-03 00:00:00
# 1993-03-04 00:00:00
# 1993-03-05 00:00:00
# 1993-03-08 00:00:00
# 1993-03-09 00:00:00
# 1993-03-10 00:00:00
# 1993-03-11 00:00:00
# 1993-03-12 00:00:00
# 1993-03-15 00:00:00
# 1993-03-16 00:00:00
# 1993-03-17 00:00:00
# 1993-03-18 00:00:00
# 1993-03-19 00:00:00
# 1993-03-22 00:00:00
# 1993-03-23 00:00:00
# 1993-03-24 00:00:00
# 1993-03-25 00:00:00
# 1993-03-26 00:00:00
# 1993-03-29 00:00:00
# 1993-03-30 00:00:00
# 1993-03-31 00:00:00
# 1993-04-01 00:00:00
# 1993-04-02 00:00:00
# 1993-04-05 00:00:00
# ...

# %%
df_m.loc["2024-02-08"]
# Out:
#               Open        High         Low       Close   Adj Close    Volume  \
# SYMBOL
# SPY     498.100006  498.709991  497.260010  498.320007  498.320007  52343600
# AMZN    169.649994  171.429993  168.880005  169.839996  169.839996  42316500
#
#         Daily Return  Historical Volatility  Annualized Volatility  macdfast  \
# SYMBOL
# SPY         0.000442               0.006981               0.110827  4.880314
# AMZN       -0.004046               0.020864               0.331211  4.321338
#
#         macdslow  macdsignal  stochslowk  stochslowd      sma_10
# SYMBOL
# SPY     4.312827    0.567487   93.394819   88.358096  491.895004
# AMZN    3.286850    1.034488   89.356196   82.721707  164.549997

# %%
df_m.xs("SPY", level=1)
