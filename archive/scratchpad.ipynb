# %%
import os
import pandas as pd

# %%
from data_loader import load_market_data

# %%
DATA_DIR='data'

# %%
files = os.listdir(DATA_DIR)

# %%
files
# Out:
# ['AMCX.csv',
#  'AMZN.csv',
#  'ASRT.csv',
#  'BABA.csv',
#  'BKE.csv',
#  'BKNG.csv',
#  'BRKR.csv',
#  'BTMD.csv',
#  'C.csv',
#  'CCSI.csv',
#  'COLL.csv',
#  'CPRX.csv',
#  'CROX.csv',
#  'CVS.csv',
#  'GOOG.csv',
#  'HCA.csv',
#  'HPQ.csv',
#  'HRMY.csv',
#  'HSII.csv',
#  'IMMR.csv',
#  'JAKK.csv',
#  'JD.csv',
#  'JILL.csv',
#  'MCFT.csv',
#  'MD.csv',
#  'MED.csv',
#  'MGM.csv',
#  'MO.csv',
#  'MTD.csv',
#  'NXST.csv',
#  'OCUP.csv',
#  'ORCL.csv',
#  'PLTK.csv',
#  'PRDO.csv',
#  'QRTEA.csv',
#  'RMNI.csv',
#  'SB.csv',
#  'SBLK.csv',
#  'SCYX.csv',
#  'SPRO.csv',
#  'SPY.csv',
#  'SURG.csv',
#  'TZOO.csv',
#  'UIS.csv',
#  'UNTC.csv',
#  'VTLE.csv',
#  'VYGR.csv',
#  'WBD.csv',
#  'ZYME.csv']

# %%
df_master = load_market_data()

# %%
df_spy = df_master.xs("SPY", level=1)

# %%
#nc = dict(zip(df_spy.columns, [ "SPY_" + c for c in df_spy.columns]))
#df_spy.rename(columns = nc, inplace = True)

# %%
df_spy
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-02-01   43.968750   44.250000   43.968750   44.250000   25.017363
# 1993-02-02   44.218750   44.375000   44.125000   44.343750   25.070370
# 1993-02-03   44.406250   44.843750   44.375000   44.812500   25.335373
# 1993-02-04   44.968750   45.093750   44.468750   45.000000   25.441376
# 1993-02-05   44.968750   45.062500   44.718750   44.968750   25.423716
# ...                ...         ...         ...         ...         ...
# 2024-02-05  493.700012  494.380005  490.230011  492.549988  492.549988
# 2024-02-06  493.519989  494.320007  492.049988  493.980011  493.980011
# 2024-02-07  496.290009  498.529999  495.359985  498.100006  498.100006
# 2024-02-08  498.100006  498.709991  497.260010  498.320007  498.320007
# 2024-02-09  498.839996  501.649994  498.489990  501.200012  501.200012
#
#               Volume  Daily Return  Historical Volatility  \
# Date
# ...

# %%
df_amzn = df_master.xs("AMZN", level=1)

# %%
df_amzn
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1997-05-16    0.098438    0.098958    0.085417    0.086458    0.086458
# 1997-05-19    0.088021    0.088542    0.081250    0.085417    0.085417
# 1997-05-20    0.086458    0.087500    0.081771    0.081771    0.081771
# 1997-05-21    0.081771    0.082292    0.068750    0.071354    0.071354
# 1997-05-22    0.071875    0.072396    0.065625    0.069792    0.069792
# ...                ...         ...         ...         ...         ...
# 2024-02-07  169.479996  170.880005  168.940002  170.529999  170.529999
# 2024-02-08  169.649994  171.429993  168.880005  169.839996  169.839996
# 2024-02-09  170.899994  175.000000  170.580002  174.449997  174.449997
# 2024-02-12  174.800003  175.389999  171.539993  172.339996  172.339996
# 2024-02-13  167.729996  170.949997  165.750000  168.639999  168.639999
#
#                Volume  Daily Return  Historical Volatility  \
# Date
# ...

# %%
df_s = df_master.xs("SPY", level=1)
df_a = df_master.xs("AMZN", level=1)

# %%
df_m=df_master

# %%
rows = df_m.loc["2024-02-08"]

# %%
for index, row in rows.iterrows():
    print(index)
# Out:
# AMCX
# AMZN
# ASRT
# BABA
# BKE
# BKNG
# BRKR
# BTMD
# C
# CCSI
# COLL
# CPRX
# CROX
# CVS
# GOOG
# HCA
# HPQ
# HRMY
# HSII
# IMMR
# JAKK
# JD
# JILL
# MCFT
# MD
# MED
# MGM
# MO
# MTD
# NXST
# OCUP
# ORCL
# PLTK
# PRDO
# QRTEA
# RMNI
# SB
# SBLK
# SCYX
# SPRO
# SPY
# SURG
# TZOO
# UIS
# UNTC
# VTLE
# VYGR
# WBD
# ZYME

# %%
df_t = df_m.loc["2024-02-08"]

# %%
df_t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, AMCX to ZYME
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Open                   49 non-null     float64
#  1   High                   49 non-null     float64
#  2   Low                    49 non-null     float64
#  3   Close                  49 non-null     float64
#  4   Adj Close              49 non-null     float64
#  5   Volume                 49 non-null     int64
#  6   Daily Return           49 non-null     float64
#  7   Historical Volatility  49 non-null     float64
#  8   Annualized Volatility  49 non-null     float64
#  9   iv                     49 non-null     float64
#  10  macdfast               49 non-null     float64
#  11  macdslow               49 non-null     float64
#  12  macdsignal             49 non-null     float64
#  13  stochslowk             49 non-null     float64
# ...

# %%
df_t
# Out:
#                Open         High          Low        Close    Adj Close  \
# SYMBOL
# AMCX      17.230000    17.230000    16.770000    17.040000    17.040000
# AMZN     169.649994   171.429993   168.880005   169.839996   169.839996
# ASRT       0.790000     0.810000     0.780000     0.790000     0.790000
# BABA      71.885002    73.199997    70.650002    70.779999    70.779999
# BKE       38.110000    38.950000    38.090000    38.750000    38.750000
# BKNG    3750.000000  3844.760010  3725.949951  3840.219971  3840.219971
# BRKR      70.720001    71.290001    70.029999    70.949997    70.949997
# BTMD       4.010000     4.070000     3.950000     3.970000     3.970000
# C         54.180000    54.490002    53.590000    54.290001    54.290001
# CCSI      20.500000    20.640000    19.190000    19.580000    19.580000
# COLL      33.270000    33.370000    32.750000    33.340000    33.340000
# CPRX      13.320000    13.500000    13.120000    13.370000    13.370000
# ...

# %%
df_t.to_dict(orient='records')
# Out:
# [{'Open': 17.23,
#   'High': 17.23,
#   'Low': 16.77,
#   'Close': 17.04,
#   'Adj Close': 17.04,
#   'Volume': 431300,
#   'Daily Return': 0.0017636684303350414,
#   'Historical Volatility': 0.03372254192156013,
#   'Annualized Volatility': 0.53532875700839,
#   'iv': 1.07065751401678,
#   'macdfast': -0.27150727203142466,
#   'macdslow': -0.1157503777248525,
#   'macdsignal': -0.15575689430657216,
#   'stochslowk': 35.692802544746414,
#   'stochslowd': 46.4559767062913,
#   'sma_10': 17.899999999999984,
#   'sma_200': 14.060100000000082},
#  {'Open': 169.649994,
#   'High': 171.429993,
#   'Low': 168.880005,
#   'Close': 169.839996,
#   'Adj Close': 169.839996,
#   'Volume': 42316500,
#   'Daily Return': -0.004046226494143101,
#   'Historical Volatility': 0.020864340969644055,
#   'Annualized Volatility': 0.33121114484960645,
#   'iv': 0.6624222896992129,
#   'macdfast': 4.321338237519285,
#   'macdslow': 3.2868501817024858,
#   'macdsignal': 1.0344880558167993,
# ...

# %%
df_t.to_json(orient='index')
# Out:
# '{"AMCX":{"Open":17.23,"High":17.23,"Low":16.77,"Close":17.04,"Adj Close":17.04,"Volume":431300,"Daily Return":0.0017636684,"Historical Volatility":0.0337225419,"Annualized Volatility":0.535328757,"iv":1.070657514,"macdfast":-0.271507272,"macdslow":-0.1157503777,"macdsignal":-0.1557568943,"stochslowk":35.6928025447,"stochslowd":46.4559767063,"sma_10":17.9,"sma_200":14.0601},"AMZN":{"Open":169.649994,"High":171.429993,"Low":168.880005,"Close":169.839996,"Adj Close":169.839996,"Volume":42316500,"Daily Return":-0.0040462265,"Historical Volatility":0.020864341,"Annualized Volatility":0.3312111448,"iv":0.6624222897,"macdfast":4.3213382375,"macdslow":3.2868501817,"macdsignal":1.0344880558,"stochslowk":89.3561959754,"stochslowd":82.7217072692,"sma_10":164.5499971,"sma_200":135.246250295},"ASRT":{"Open":0.79,"High":0.81,"Low":0.78,"Close":0.79,"Adj Close":0.79,"Volume":495200,"Daily Return":0.0,"Historical Volatility":0.033866901,"Annualized Volatility":0.5376203862,"iv":1.0752407725,"macdfa
# ...

# %%
dd =df_t.to_dict(orient='index')

# %%
data = {}
for symbol, row in df_t.iterrows():
    data[symbol] = dotdict(row)

# %%
data
# Out:
# {'AMCX': {'Open': 17.23,
#   'High': 17.23,
#   'Low': 16.77,
#   'Close': 17.04,
#   'Adj Close': 17.04,
#   'Volume': 431300.0,
#   'Daily Return': 0.0017636684303350414,
#   'Historical Volatility': 0.03372254192156013,
#   'Annualized Volatility': 0.53532875700839,
#   'iv': 1.07065751401678,
#   'macdfast': -0.27150727203142466,
#   'macdslow': -0.1157503777248525,
#   'macdsignal': -0.15575689430657216,
#   'stochslowk': 35.692802544746414,
#   'stochslowd': 46.4559767062913,
#   'sma_10': 17.899999999999984,
#   'sma_200': 14.060100000000082},
#  'AMZN': {'Open': 169.649994,
#   'High': 171.429993,
#   'Low': 168.880005,
#   'Close': 169.839996,
#   'Adj Close': 169.839996,
#   'Volume': 42316500.0,
#   'Daily Return': -0.004046226494143101,
#   'Historical Volatility': 0.020864340969644055,
#   'Annualized Volatility': 0.33121114484960645,
#   'iv': 0.6624222896992129,
#   'macdfast': 4.321338237519285,
#   'macdslow': 3.2868501817024858,
# ...

# %%
print(dd.get("SPYY"))
# Out:
# None

# %%
if dd.get("SPYY"):
    print("success")
else:
    print("fail")
# Out:
# fail

# %%
class dotdict(dict):
    """dot.notation access to dictionary attributes"""
    __getattr__ = dict.get
    __setattr__ = dict.__setitem__
    __delattr__ = dict.__delitem__

# %%
df_t.to_dict(orient='tight' )
# Out:
# {'index': ['AMCX',
#   'AMZN',
#   'ASRT',
#   'BABA',
#   'BKE',
#   'BKNG',
#   'BRKR',
#   'BTMD',
#   'C',
#   'CCSI',
#   'COLL',
#   'CPRX',
#   'CROX',
#   'CVS',
#   'GOOG',
#   'HCA',
#   'HPQ',
#   'HRMY',
#   'HSII',
#   'IMMR',
#   'JAKK',
#   'JD',
#   'JILL',
#   'MCFT',
#   'MD',
#   'MED',
#   'MGM',
#   'MO',
#   'MTD',
#   'NXST',
#   'OCUP',
#   'ORCL',
#   'PLTK',
#   'PRDO',
#   'QRTEA',
#   'RMNI',
#   'SB',
#   'SBLK',
#   'SCYX',
#   'SPRO',
#   'SPY',
#   'SURG',
#   'TZOO',
#   'UIS',
#   'UNTC',
#   'VTLE',
#   'VYGR',
#   'WBD',
#   'ZYME'],
#  'columns': ['Open',
#   'High',
#   'Low',
#   'Close',
#   'Adj Close',
#   'Volume',
#   'Daily Return',
#   'Historical Volatility',
#   'Annualized Volatility',
#   'iv',
#   'macdfast',
#   'macdslow',
#   'macdsignal',
#   'stochslowk',
#   'stochslowd',
#   'sma_10',
#   'sma_200'],
#  'data': [[17.23,
#    17.23,
#    16.77,
#    17.04,
#    17.04,
#    431300,
#    0.0017636684303350414,
# ...

# %%
type(dd2)
# Out:
# __main__.dotdict

# %%
type(dd2.get("AMZN"))
# Out:
# dict

# %%
sd = df_t.xs("AMZN")

# %%
sd.name
# Out:
# 'AMZN'

# %%
sd.Close
# Out:
# 169.839996

# %%
sd2=df_t.T.get('AMZN')

# %%
sd2.Close
# Out:
# 169.839996

# %%
sd2.index.value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 sd2.index.value
#
# AttributeError: 'Index' object has no attribute 'value'

# %%
sd3=df_t.T.get('AMAZN')

# %%
nc = dict(zip(df_spy.columns, [ "SPY_" + c for c in df_spy.columns]))

# %%
'AMAZN'.lower()
# Out:
# 'amazn'

# %%
print(sd3)
# Out:
# None

# %%
for index, row in df_m.xs("SPY", level=1).iterrows():
    print(index)
# Out:
# 1993-02-01 00:00:00
# 1993-02-02 00:00:00
# 1993-02-03 00:00:00
# 1993-02-04 00:00:00
# 1993-02-05 00:00:00
# 1993-02-08 00:00:00
# 1993-02-09 00:00:00
# 1993-02-10 00:00:00
# 1993-02-11 00:00:00
# 1993-02-12 00:00:00
# 1993-02-16 00:00:00
# 1993-02-17 00:00:00
# 1993-02-18 00:00:00
# 1993-02-19 00:00:00
# 1993-02-22 00:00:00
# 1993-02-23 00:00:00
# 1993-02-24 00:00:00
# 1993-02-25 00:00:00
# 1993-02-26 00:00:00
# 1993-03-01 00:00:00
# 1993-03-02 00:00:00
# 1993-03-03 00:00:00
# 1993-03-04 00:00:00
# 1993-03-05 00:00:00
# 1993-03-08 00:00:00
# 1993-03-09 00:00:00
# 1993-03-10 00:00:00
# 1993-03-11 00:00:00
# 1993-03-12 00:00:00
# 1993-03-15 00:00:00
# 1993-03-16 00:00:00
# 1993-03-17 00:00:00
# 1993-03-18 00:00:00
# 1993-03-19 00:00:00
# 1993-03-22 00:00:00
# 1993-03-23 00:00:00
# 1993-03-24 00:00:00
# 1993-03-25 00:00:00
# 1993-03-26 00:00:00
# 1993-03-29 00:00:00
# 1993-03-30 00:00:00
# 1993-03-31 00:00:00
# 1993-04-01 00:00:00
# 1993-04-02 00:00:00
# 1993-04-05 00:00:00
# ...

# %%
df_m.loc["2024-02-08"]
# Out:
#               Open        High         Low       Close   Adj Close    Volume  \
# SYMBOL
# SPY     498.100006  498.709991  497.260010  498.320007  498.320007  52343600
# AMZN    169.649994  171.429993  168.880005  169.839996  169.839996  42316500
#
#         Daily Return  Historical Volatility  Annualized Volatility  macdfast  \
# SYMBOL
# SPY         0.000442               0.006981               0.110827  4.880314
# AMZN       -0.004046               0.020864               0.331211  4.321338
#
#         macdslow  macdsignal  stochslowk  stochslowd      sma_10
# SYMBOL
# SPY     4.312827    0.567487   93.394819   88.358096  491.895004
# AMZN    3.286850    1.034488   89.356196   82.721707  164.549997

# %%
df_m.xs("SPY", level=1)
